# %%
import pandas as pd
import time
import requests
from statsmodels.tsa.ar_model import AutoReg as AR
from src.src import *
import pickle
import os

# %%
country_codes=pd.read_csv('data/country_codes.csv')

# %%
country_codes.head()
# Out:
#              name alpha-2 alpha-3   region       sub-region
# 0     Afghanistan      AF     AFG     Asia    Southern Asia
# 1   Åland Islands      AX     ALA   Europe  Northern Europe
# 2         Albania      AL     ALB   Europe  Southern Europe
# 3         Algeria      DZ     DZA   Africa  Northern Africa
# 4  American Samoa      AS     ASM  Oceania        Polynesia

# %%
indicators=['SP.DYN.CBRT.IN','SP.DYN.CDRT.IN']
#Death rate, crude (per 1,000 people): SP.DYN.CDRT.IN
#Birth rate, crude (per 1,000 people): SP.DYN.CBRT.IN
countries=list(country_codes['alpha-2'])
countries.append('World')

# %%
i=indicators[1]
data=get_data(i,countries)

# %%
resultado=get_df(data)
resultado=resultado.merge(country_codes[['name','alpha-2','sub-region']], how='inner',left_on=['country'],right_on=['alpha-2'])
# Out:
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# ...
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\Anaconda3\envs\clase1\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Alberto\git_yo\final\b\src\src.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultado=resultado.append({'country':z,'error2019':error2019,'error2020':error2020},ignore_index=True)

# %%
resultado.drop(labels='country',axis=1,inplace=True)

# %%
#resultado.error2019=resultado.error2019*100
#resultado.error2020=resultado.error2020*100

# %%
resultado.to_csv('data/natality_errors.csv')

# %%
resultado[resultado.name=='Spain']
# Out:
#     error2019 error2020   name alpha-2       sub-region
# 160 -0.030516  0.151385  Spain      ES  Southern Europe
